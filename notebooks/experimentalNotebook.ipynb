# %%
# !nvidia-smi
# Out:
# Tue Apr  7 06:21:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/samy1406/defect-classifier-resnet.git
# %cd defect-classifier-resnet
# Out:
# Cloning into 'defect-classifier-resnet'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 42 (delta 0), reused 2 (delta 0), pack-reused 38 (from 1)
# Receiving objects: 100% (42/42), 39.81 MiB | 42.03 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/defect-classifier-resnet/defect-classifier-resnet

# %%
# !pip install torch torchvision -q

# %%
# !pip install kaggle -q
import os
os.makedirs("/root/.kaggle", exist_ok=True)

# %%
kaggle_creds = {"username":"YOUR_KAGGLE_USERNAME","key":"YOUR_KAGGLE_API_KEY"}

# %%
# !kaggle datasets download -d akhatova/pcb-defects -p raw_data/ --unzip
# !python src/prepare_dataset.py
# Out:
# Dataset URL: https://www.kaggle.com/datasets/akhatova/pcb-defects
# License(s): unknown
# ...
# 100% 1.88G/1.88G [00:11<00:00, 178MB/s]
#
# Spur: 343 train | 75 val | 70 test crops
# Mouse_bite: 347 train | 71 val | 74 test crops
# Spurious_copper: 352 train | 77 val | 74 test crops
# Missing_hole: 345 train | 74 val | 78 test crops
# Short: 356 train | 70 val | 65 test crops
# Open_circuit: 335 train | 75 val | 72 test crops

# %%
# !python src/train.py
# Out:
# Using device: cuda
# Classes: ['Missing_hole', 'Mouse_bite', 'Open_circuit', 'Short', 'Spur', 'Spurious_copper']
# Epoch [1/10] Train Loss: 1.4900 Acc: 40.09% | Val Loss: 1.2684 Acc: 55.66%
#   --> Best model saved (val_acc: 55.66%)
# Epoch [2/10] Train Loss: 1.0964 Acc: 62.90% | Val Loss: 1.0007 Acc: 64.03%
#   --> Best model saved (val_acc: 64.03%)
# Epoch [3/10] Train Loss: 0.9567 Acc: 69.20% | Val Loss: 0.8943 Acc: 67.87%
#   --> Best model saved (val_acc: 67.87%)
# Epoch [4/10] Train Loss: 0.8318 Acc: 74.74% | Val Loss: 0.7794 Acc: 72.17%
#   --> Best model saved (val_acc: 72.17%)
# Epoch [5/10] Train Loss: 0.8001 Acc: 73.53% | Val Loss: 0.7661 Acc: 75.57%
#   --> Best model saved (val_acc: 75.57%)
# Epoch [6/10] Train Loss: 0.7393 Acc: 76.37% | Val Loss: 0.7163 Acc: 74.43%
# Epoch [7/10] Train Loss: 0.6805 Acc: 78.15% | Val Loss: 0.7047 Acc: 76.02%
#   --> Best model saved (val_acc: 76.02%)
# Epoch [8/10] Train Loss: 0.6779 Acc: 77.77% | Val Loss: 0.6276 Acc: 79.64%
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 368 bytes | 73.00 KiB/s, done.
# From https://github.com/samy1406/defect-classifier-resnet
#    f3e6a8f..cf7dd5a  main       -> origin/main
# Updating f3e6a8f..cf7dd5a
# Fast-forward
#  src/train.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !python src/train.py
# Out:
# Using device: cuda
# Classes: ['Missing_hole', 'Mouse_bite', 'Open_circuit', 'Short', 'Spur', 'Spurious_copper']
# Epoch [1/10] Train Loss: 0.6939 Acc: 76.61% | Val Loss: 0.1494 Acc: 96.15%
#   --> Best model saved (val_acc: 96.15%)
# Epoch [2/10] Train Loss: 0.1244 Acc: 96.44% | Val Loss: 0.0763 Acc: 97.51%
#   --> Best model saved (val_acc: 97.51%)
# Epoch [3/10] Train Loss: 0.0543 Acc: 98.85% | Val Loss: 0.0529 Acc: 98.87%
#   --> Best model saved (val_acc: 98.87%)
# Epoch [4/10] Train Loss: 0.0415 Acc: 98.99% | Val Loss: 0.0497 Acc: 98.87%
# Epoch [5/10] Train Loss: 0.0305 Acc: 99.42% | Val Loss: 0.0764 Acc: 98.42%
# Epoch [6/10] Train Loss: 0.0127 Acc: 99.90% | Val Loss: 0.0463 Acc: 99.10%
#   --> Best model saved (val_acc: 99.10%)
# Epoch [7/10] Train Loss: 0.0101 Acc: 99.95% | Val Loss: 0.0468 Acc: 98.87%
# Epoch [8/10] Train Loss: 0.0115 Acc: 99.76% | Val Loss: 0.0541 Acc: 98.64%
# Epoch [9/10] Train Loss: 0.0094 Acc: 99.86% | Val Loss: 0.0602 Acc: 98.64%
# ...

# %%
# !rm -rf data/
# !python src/prepare_dataset.py
# Out:
# Spur: 343 train | 75 val | 70 test crops
# Mouse_bite: 347 train | 71 val | 74 test crops
# Spurious_copper: 352 train | 77 val | 74 test crops
# Missing_hole: 345 train | 74 val | 78 test crops
# Short: 356 train | 70 val | 65 test crops
# Open_circuit: 335 train | 75 val | 72 test crops

# %%
# !python src/train.py
# Out:
# Using device: cuda
# Classes: ['Missing_hole', 'Mouse_bite', 'Open_circuit', 'Short', 'Spur', 'Spurious_copper']
# Epoch [1/10] Train Loss: 0.7005 Acc: 77.29% | Val Loss: 0.1751 Acc: 95.25%
#   --> Best model saved (val_acc: 95.25%)
# Epoch [2/10] Train Loss: 0.1272 Acc: 96.44% | Val Loss: 0.0941 Acc: 97.51%
#   --> Best model saved (val_acc: 97.51%)
# Epoch [3/10] Train Loss: 0.0570 Acc: 98.36% | Val Loss: 0.0783 Acc: 98.42%
#   --> Best model saved (val_acc: 98.42%)
# Epoch [4/10] Train Loss: 0.0336 Acc: 99.37% | Val Loss: 0.0501 Acc: 98.64%
#   --> Best model saved (val_acc: 98.64%)
# Epoch [5/10] Train Loss: 0.0213 Acc: 99.90% | Val Loss: 0.0559 Acc: 98.87%
#   --> Best model saved (val_acc: 98.87%)
# Epoch [6/10] Train Loss: 0.0195 Acc: 99.47% | Val Loss: 0.0395 Acc: 99.10%
#   --> Best model saved (val_acc: 99.10%)
# Epoch [7/10] Train Loss: 0.0186 Acc: 99.52% | Val Loss: 0.0511 Acc: 98.64%
# Epoch [8/10] Train Loss: 0.0163 Acc: 99.66% | Val Loss: 0.0429 Acc: 98.87%
# ...

# %%
# !python -m src.evaluate
# Out:
# Using device: cuda
#
# Test Accuracy: 97.46%
#
# Per-class Accuracy:
#   Missing_hole        : 100.00%
#   Mouse_bite          : 94.59%
#   Open_circuit        : 100.00%
#   Short               : 100.00%
#   Spur                : 90.00%
#   Spurious_copper     : 100.00%
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#    Missing_hole       0.99      1.00      0.99        78
#      Mouse_bite       0.95      0.95      0.95        74
#    Open_circuit       0.99      1.00      0.99        72
#           Short       0.97      1.00      0.98        65
#            Spur       0.98      0.90      0.94        70
# Spurious_copper       0.97      1.00      0.99        74
#
#        accuracy                           0.97       433
#       macro avg       0.97      0.97      0.97       433
#    weighted avg       0.97      0.97      0.97       433
#
# Figure(1000x800)
#
# Confusion matrix saved as confusion_matrix_finetune.png

# %%
# !git add -f best_model_finetune.pth confusion_matrix_finetune.png

# %%
# !git commit -m "feat: add evaluation results (test acc: 97.46%)"
# Out:
# [main c9fa10b] feat: add evaluation results (test acc: 97.46%)
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 confusion_matrix_finetune.png

# %%
# !git push
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 39.69 MiB | 12.71 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/samy1406/defect-classifier-resnet.git
#    e74e9c2..c9fa10b  main -> main
